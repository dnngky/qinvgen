# %%
from circuits import *

# %%
example_1().draw(output='mpl', initial_state=True)

# %%
qwalk_2(export=True).draw(output='mpl', initial_state=True)

# %%
qwalk_3(export=True).draw(output='mpl', initial_state=True)
